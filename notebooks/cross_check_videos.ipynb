# %%
import pandas as pd

# %%
def cross_check_records(check_video_type = None, input_file = "../table_tennis_data/metadata/game.xlsx"):
    # Read Excel sheets
    df_game = pd.read_excel(input_file, sheet_name="game")
    df_game_player = pd.read_excel(input_file, sheet_name="game_player")
    df_game_player_item = pd.read_excel(input_file, sheet_name="game_player_item")
    df_game_player_double_item = pd.read_excel(input_file, sheet_name="game_player_double_item")

    # Ensure required columns exist
    required_cols = {
        "game": ["Id"],
        "game_player": ["GameId", "PlayerId"],
        "game_player_item": ["GamePlayerId"],
        "game_player_double_item": ["GamePlayerId"],
    }

    for name, cols in required_cols.items():
        df = {
            "game": df_game,
            "game_player": df_game_player,
            "game_player_item": df_game_player_item,
            "game_player_double_item": df_game_player_double_item,
        }[name]

        for col in cols:
            if col not in df.columns:
                raise ValueError(f"Missing column '{col}' in {name} file.")

    # Convert gameplayerid to set for fast lookup
    item_ids = set(df_game_player_item["GamePlayerId"].tolist()) | set(df_game_player_double_item["GamePlayerId"].tolist())

    results = []

    # to get the non-player missing game ids
    non_missing_game_ids = []

    # Process each game.id
    for _, row in df_game.iterrows():

        game_id = row["Id"]
        video_type = row["VideoType"]
        if check_video_type:
            if video_type != check_video_type:
                continue

        # Step 1: Find all players for this game
        players = df_game_player[df_game_player["GameId"] == game_id]["Id"].tolist()

        # Step 2: Check each player_id against game_player_item
        missing = [pid for pid in players if pid not in item_ids]
        existing = [pid for pid in players if pid in item_ids]
        if missing == [] and existing != []: non_missing_game_ids.append(game_id)

        results.append({
            "game_id": game_id,
            "total_players": len(players),
            "players_found_in_item": existing,
            "players_missing_in_item": missing
        })

    return results, non_missing_game_ids

# %%
results, non_missing_game_ids = cross_check_records(check_video_type="File")
for r in results:
    print("\nGame ID:", r["game_id"])
    print("Found players:", r["players_found_in_item"])
    print("Missing players:", r["players_missing_in_item"])
# Out:
# Game ID: 357
# Found players: []
# Missing players: []
#
# Game ID: 387
# Found players: []
# Missing players: [749, 750]
#
# Game ID: 413
# Found players: [795, 796]
# Missing players: []
#
# Game ID: 436
# Found players: []
# Missing players: [906, 907]
#
# Game ID: 437
# Found players: [908, 909]
# Missing players: []
#
# Game ID: 439
# Found players: [925, 926, 927, 928]
# Missing players: []
#
# Game ID: 440
# Found players: [949, 950, 951, 952]
# Missing players: []
#
# Game ID: 444
# Found players: [953, 954, 955, 956]
# Missing players: []
#
# Game ID: 445
# Found players: [957, 958, 959, 960]
# Missing players: []
#
# Game ID: 446
# Found players: []
# Missing players: []
#
# Game ID: 448
# Found players: []
# Missing players: [961, 962]
#
# Game ID: 449
# Found players: []
# Missing players: [963, 964]
#
# Game ID: 450
# Found players: []
# Missing players: [965, 966]
#
# Game ID: 451
# Found players: []
# Missing players: [967, 968]
#
# Game ID: 452
# Found players: [969, 970]
# Missing players: []
#
# Game ID: 453
# Found players: [971, 972]
# Missing players: []
#
# Game ID: 454
# Found players: []
# Missing players: []
#
# Game ID: 455
# Found players: []
# Missing players: [973, 974]
#
# Game ID: 456
# Found players: []
# Missing players: [975, 976]
#
# Game ID: 457
# Found players: [977, 978]
# Missing players: []
#
# Game ID: 458
# Found players: []
# Missing players: [979, 980]
#
# Game ID: 459
# Found players: []
# Missing players: [981, 982]
#
# Game ID: 460
# Found players: []
# Missing players: [983, 984]
#
# Game ID: 461
# Found players: [985, 986]
# Missing players: []
#
# Game ID: 462
# Found players: [987, 988, 989, 990]
# Missing players: []
#
# Game ID: 465
# Found players: [1005, 1006, 1007, 1008]
# Missing players: []
#
# Game ID: 466
# Found players: [1009, 1010, 1011, 1012]
# Missing players: []
#
# Game ID: 467
# Found players: [1013, 1014]
# Missing players: []
#
# Game ID: 468
# Found players: [1015, 1016]
# Missing players: []
#
# Game ID: 469
# Found players: [1017, 1018]
# Missing players: []
#
# Game ID: 472
# Found players: [1027, 1028]
# Missing players: []
#
# Game ID: 473
# Found players: [1029, 1030]
# Missing players: []
#
# Game ID: 474
# Found players: []
# Missing players: []
#
# Game ID: 475
# Found players: [1035, 1036, 1037, 1038]
# Missing players: []
#
# Game ID: 476
# Found players: [1043, 1044, 1045, 1046]
# Missing players: []
#
# Game ID: 477
# Found players: [1047, 1048]
# Missing players: []
#
# Game ID: 478
# Found players: []
# Missing players: [1049, 1050]
#
# Game ID: 479
# Found players: []
# Missing players: [1051, 1052]
#
# Game ID: 480
# Found players: []
# Missing players: [1053, 1054]
#
# Game ID: 481
# Found players: []
# Missing players: [1055, 1056]
#
# Game ID: 482
# Found players: []
# Missing players: [1057, 1058]
#
# Game ID: 483
# Found players: [1059, 1060]
# Missing players: []
#
# Game ID: 484
# Found players: []
# Missing players: [1061, 1062]
#
# Game ID: 485
# Found players: [1063, 1064]
# Missing players: []
#
# Game ID: 486
# Found players: [1065, 1066, 1067, 1068]
# Missing players: []
#
# Game ID: 487
# Found players: [1069, 1070]
# Missing players: []
#
# Game ID: 489
# Found players: [1077, 1078, 1079, 1080]
# Missing players: []
#
# Game ID: 490
# Found players: [1081, 1082, 1083, 1084]
# Missing players: []
#
# Game ID: 491
# Found players: [1093, 1094, 1095, 1096]
# Missing players: []
#
# Game ID: 492
# Found players: [1097, 1098, 1099, 1100]
# Missing players: []
#
# Game ID: 493
# Found players: [1113, 1114, 1115, 1116]
# Missing players: []
#
# Game ID: 494
# Found players: [1121, 1122, 1123, 1124]
# Missing players: []
#
# Game ID: 497
# Found players: [1129, 1130]
# Missing players: []
#
# Game ID: 498
# Found players: []
# Missing players: [1131, 1132]
#
# Game ID: 499
# Found players: []
# Missing players: [1133, 1134]
#
# Game ID: 500
# Found players: []
# Missing players: [1135, 1136]
#
# Game ID: 501
# Found players: [1137, 1138, 1139, 1140]
# Missing players: []
#
# Game ID: 502
# Found players: [1141, 1142, 1143, 1144]
# Missing players: []
#
# Game ID: 503
# Found players: []
# Missing players: [1145, 1146, 1147, 1148]
#
# Game ID: 504
# Found players: [1149, 1150, 1151, 1152]
# Missing players: []
#
# Game ID: 505
# Found players: [1153, 1154, 1155, 1156]
# Missing players: []
#
# Game ID: 506
# Found players: [1157, 1158, 1159, 1160]
# Missing players: []
#
# Game ID: 508
# Found players: [1165, 1166]
# Missing players: []
#
# Game ID: 513
# Found players: [1175, 1176]
# Missing players: []
#
# Game ID: 520
# Found players: [1187, 1188, 1189, 1190]
# Missing players: []
#
# Game ID: 521
# Found players: [1191, 1192, 1193, 1194]
# Missing players: []
#
# Game ID: 527
# Found players: [1207, 1208, 1209, 1210]
# Missing players: []
#
# Game ID: 528
# Found players: [1211, 1212, 1213, 1214]
# Missing players: []
#
# Game ID: 529
# Found players: [1215, 1216, 1217, 1218]
# Missing players: []
#
# Game ID: 530
# Found players: [1219, 1220, 1221, 1222]
# Missing players: []
#
# Game ID: 531
# Found players: [1223, 1224, 1225, 1226]
# Missing players: []
#
# Game ID: 532
# Found players: []
# Missing players: []
#
# Game ID: 533
# Found players: [1227, 1228, 1229, 1230]
# Missing players: []
#
# Game ID: 534
# Found players: []
# Missing players: []
#
# Game ID: 535
# Found players: [1231, 1232, 1233, 1234]
# Missing players: []
#
# Game ID: 536
# Found players: [1235, 1236, 1237, 1238]
# Missing players: []
#
# Game ID: 537
# Found players: [1239, 1240, 1241, 1242]
# Missing players: []
#
# Game ID: 538
# Found players: [1243, 1244, 1245, 1246]
# Missing players: []
#
# Game ID: 541
# Found players: [1249, 1250, 1251, 1252]
# Missing players: []
#
# Game ID: 542
# Found players: [1253, 1254, 1255, 1256]
# Missing players: []
#
# Game ID: 543
# Found players: [1257, 1258, 1259, 1260]
# Missing players: []
#
# Game ID: 544
# Found players: [1261, 1262, 1263, 1264]
# Missing players: []
#
# Game ID: 545
# Found players: [1265, 1266, 1267, 1268]
# Missing players: []
#
# Game ID: 546
# Found players: [1269, 1270, 1271, 1272]
# Missing players: []
#
# Game ID: 547
# Found players: [1273, 1274, 1275, 1276]
# Missing players: []
#
# Game ID: 548
# Found players: [1277, 1278, 1279, 1280]
# Missing players: []
#
# Game ID: 549
# Found players: [1281, 1282, 1283, 1284]
# Missing players: []
#
# Game ID: 550
# Found players: [1285, 1286, 1287, 1288]
# Missing players: []
#
# Game ID: 551
# Found players: [1289, 1290, 1291, 1292]
# Missing players: []
#
# Game ID: 552
# Found players: [1293, 1294, 1295, 1296]
# Missing players: []
#
# Game ID: 553
# Found players: [1297, 1298, 1299, 1300]
# Missing players: []
#
# Game ID: 555
# Found players: [1303, 1304, 1305, 1306]
# Missing players: []
#
# Game ID: 556
# Found players: [1307, 1308, 1309, 1310]
# Missing players: []
#
# Game ID: 560
# Found players: [1317, 1318]
# Missing players: []
#
# Game ID: 561
# Found players: [1319, 1320]
# Missing players: []
#
# Game ID: 562
# Found players: [1321, 1322]
# Missing players: []
#
# Game ID: 563
# Found players: [1323, 1324]
# Missing players: []
#
# Game ID: 564
# Found players: [1325, 1326]
# Missing players: []
#
# Game ID: 565
# Found players: [1327, 1328]
# Missing players: []
#
# Game ID: 566
# Found players: [1329, 1330]
# Missing players: []
#
# Game ID: 569
# Found players: [1335, 1336]
# Missing players: []
#
# Game ID: 570
# Found players: [1337, 1338]
# Missing players: []
#
# Game ID: 571
# Found players: [1339, 1340]
# Missing players: []
#
# Game ID: 575
# Found players: [1345, 1346, 1347, 1348]
# Missing players: []
#
# Game ID: 576
# Found players: [1349, 1350, 1351, 1352]
# Missing players: []
#
# Game ID: 577
# Found players: [1353, 1354, 1355, 1356]
# Missing players: []
#
# Game ID: 598
# Found players: [1396, 1397, 1398, 1399]
# Missing players: []
#
# Game ID: 599
# Found players: [1400, 1401, 1402, 1403]
# Missing players: []
#
# Game ID: 600
# Found players: [1404, 1405, 1406, 1407]
# Missing players: []
#
# Game ID: 601
# Found players: [1408, 1409, 1410, 1411]
# Missing players: []
#
# Game ID: 603
# Found players: [1412, 1413, 1414, 1415]
# Missing players: []
#
# Game ID: 605
# Found players: [1418, 1419, 1420, 1421]
# Missing players: []
#
# Game ID: 609
# Found players: [1428, 1429, 1430, 1431]
# Missing players: []
#
# Game ID: 610
# Found players: [1432, 1433, 1434, 1435]
# Missing players: []
#
# Game ID: 620
# Found players: [1511, 1512, 1513, 1514]
# Missing players: []
#
# Game ID: 621
# Found players: [1515, 1516, 1517, 1518]
# Missing players: []
#
# Game ID: 622
# Found players: [1519, 1520, 1521, 1522]
# Missing players: []
#
# Game ID: 623
# Found players: [1523, 1524, 1525, 1526]
# Missing players: []
#
# Game ID: 625
# Found players: [1531, 1532, 1533, 1534]
# Missing players: []
#
# Game ID: 12914
# Found players: [1556, 1557]
# Missing players: []
#
# Game ID: 12918
# Found players: [1564, 1565, 1566, 1567]
# Missing players: []
#
# Game ID: 12920
# Found players: [1570, 1571, 1572, 1573]
# Missing players: []
#
# Game ID: 12924
# Found players: [1598, 1599, 1600, 1601]
# Missing players: []
#
# Game ID: 12933
# Found players: [1660, 1661]
# Missing players: []
#
# Game ID: 12941
# Found players: [1676, 1677]
# Missing players: []
#
# Game ID: 12942
# Found players: [1678, 1679]
# Missing players: []
#
# Game ID: 12967
# Found players: [1734, 1735]
# Missing players: []
#
# Game ID: 12971
# Found players: [1742, 1743]
# Missing players: []
#
# Game ID: 12972
# Found players: [1744, 1745]
# Missing players: []
#
# Game ID: 12973
# Found players: [1746, 1747]
# Missing players: []
#
# Game ID: 12978
# Found players: [1764, 1765, 1766, 1767]
# Missing players: []
#
# Game ID: 12979
# Found players: [1768, 1769, 1770, 1771]
# Missing players: []
#
# Game ID: 12980
# Found players: [1772, 1773]
# Missing players: []
#
# Game ID: 12981
# Found players: [1774, 1775, 1776, 1777]
# Missing players: []
#
# Game ID: 12986
# Found players: [1792, 1793]
# Missing players: []
#
# Game ID: 12988
# Found players: [1798, 1799]
# Missing players: []
#
# Game ID: 12992
# Found players: [1808, 1809, 1810, 1811]
# Missing players: []
#
# Game ID: 12993
# Found players: [1812, 1813, 1814, 1815]
# Missing players: []
#
# Game ID: 12994
# Found players: [1816, 1817, 1818, 1819]
# Missing players: []
#
# Game ID: 12998
# Found players: [1828, 1829]
# Missing players: []

# %%
print(non_missing_game_ids)
# Out:
# [413, 437, 439, 440, 444, 445, 452, 453, 457, 461, 462, 465, 466, 467, 468, 469, 472, 473, 475, 476, 477, 483, 485, 486, 487, 489, 490, 491, 492, 493, 494, 497, 501, 502, 504, 505, 506, 508, 513, 520, 521, 527, 528, 529, 530, 531, 533, 535, 536, 537, 538, 541, 542, 543, 544, 545, 546, 547, 548, 549, 550, 551, 552, 553, 555, 556, 560, 561, 562, 563, 564, 565, 566, 569, 570, 571, 575, 576, 577, 598, 599, 600, 601, 603, 605, 609, 610, 620, 621, 622, 623, 625, 12914, 12918, 12920, 12924, 12933, 12941, 12942, 12967, 12971, 12972, 12973, 12978, 12979, 12980, 12981, 12986, 12988, 12992, 12993, 12994, 12998]
