# %%
import pickle
import numpy as np

with open("../table_tennis_data/clip_A000.pkl", "rb") as f:
    data = pickle.load(f)

print("Keys in PKL:", data.keys())

print("keypoint shape:", np.array(data["keypoint"]).shape)

if "bbox" in data:
    print("bbox shape:", np.array(data["bbox"]).shape)
print()
# Out:
# Keys in PKL: dict_keys(['keypoint', 'keypoint_score', 'frame_dir', 'img_shape', 'original_shape', 'total_frames', 'label'])
# keypoint shape: (7, 364, 17, 2)
